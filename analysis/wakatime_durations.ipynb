# %%
from datetime import date, datetime as dt, timedelta as td
import numpy as np
import pandas as pd
import datetime

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
# %matplotlib inline

# %%
durations = pd.read_csv('../data/wakatime_durations.csv')
# if exists remove old index columns
durations.drop(['Unnamed: 0'], axis=1, inplace=True)
durations
# Out:
#                           time            project      duration
# 0   2023-10-20 10:58:10.719354            spotify      0.000000
# 1   2023-10-20 13:20:05.720760  personal-influxdb    570.165223
# 2   2023-10-20 13:29:35.885983            spotify      7.009283
# 3   2023-10-20 13:29:42.895266  personal-influxdb      6.491415
# 4   2023-10-20 13:29:49.386681            spotify      6.760659
# 5   2023-10-20 13:29:56.147340  personal-influxdb    345.776641
# 6   2023-10-20 14:52:41.196807  personal-influxdb      1.374618
# 7   2023-10-20 14:52:42.571425            spotify    106.460301
# 8   2023-10-20 14:54:29.031726  personal-influxdb    512.156974
# 9   2023-10-20 15:03:01.188700            spotify      0.000000
# 10  2023-10-20 15:33:14.481718            spotify  10172.053995
# 11  2023-10-21 17:33:32.735427            spotify    176.976293
# 12  2023-10-22 06:18:05.120785            spotify   3081.478932
# 13  2023-10-22 14:24:51.727856            spotify   7814.032130
# ...

# %%
# make a 1d bar with time and duration of each event for spotify
# first separate by day
spotify = durations[durations['project']=="spotify"]
spotify['date'] = pd.to_datetime(spotify['time']).dt.date
# spotify['date'] = spotify['date'].dt.date
# now get the time of the day
spotify['time'] = pd.to_datetime(spotify['time']).dt.time
spotify
# Out:
# C:\Users\james\AppData\Local\Temp\ipykernel_20064\1422890998.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spotify['date'] = pd.to_datetime(spotify['time']).dt.date
# C:\Users\james\AppData\Local\Temp\ipykernel_20064\1422890998.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spotify['time'] = pd.to_datetime(spotify['time']).dt.time
#                time  project      duration        date
# 0   10:58:10.719354  spotify      0.000000  2023-10-20
# ...

# %%
intervals = []
for i, row in spotify[spotify['date'] == datetime.datetime.strptime("2023-10-24", '%Y-%m-%d').date()].iterrows():
    timing_h = row['time'].hour+row['time'].minute/60+row['time'].second/3600
    intervals.append([timing_h, timing_h+row['duration']/3600])

# %%
intervals
# Out:
# [[7.488611111111111, 11.826707376111111],
#  [13.621111111111112, 13.728239417222223],
#  [13.993888888888888, 18.00289030833333],
#  [18.489166666666666, 19.436252091944443],
#  [20.22083333333333, 22.12829233222222]]
