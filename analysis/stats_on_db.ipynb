# %%
from Database import Database
import pandas as pd

# %%
db = Database(username = '', password = '', data_base = "")
db_data = db.get_all()

# %%
df = pd.DataFrame(db_data)
columns = db.get_column_names()
columns = [col[0] for col in columns]

# %%
# set df columns with columns retrieved
df.columns = columns
df
# Out:
#                                                     name  danceability  \
# 0                                                  D.Y.D         0.749
# 1                                           Cough It Out         0.256
# 2                                            Future Love         0.766
# 3                                               Himawari         0.928
# 4                                              Survivors         0.391
# ...                                                  ...           ...
# 18015                                         Once Again         0.325
# 18016  Chopin: Nocturne No. 20 in C-Sharp Minor, Op. ...         0.225
# 18017  Variations on a Rococo Theme, Op. 33, TH 57: V...         0.119
# 18018                                   Gnossienne No. 1         0.376
# 18019      Liebestraum No. 3 in A-Flat Major, S. 541 / 3         0.279
#
#         energy  key  loudness  mode  speechiness  acousticness  \
# ...

# %%
# make statistics on the dataframe numerical columns
df.describe()
# Out:
#        danceability        energy           key      loudness          mode  \
# count  18020.000000  18020.000000  18020.000000  18020.000000  18020.000000
# mean       0.531347      0.652282      5.219756     -9.366994      0.642564
# std        0.192749      0.300472      3.599025      7.553233      0.479258
# min        0.000000      0.000020      0.000000    -45.585000      0.000000
# 25%        0.389000      0.468000      2.000000    -10.457000      0.000000
# 50%        0.526000      0.733000      5.000000     -6.665000      1.000000
# 75%        0.684000      0.914000      8.000000     -4.728750      1.000000
# max        0.981000      1.000000     11.000000      3.647000      1.000000
#
#         speechiness  acousticness  instrumentalness      liveness  \
# count  18020.000000  18020.000000      18020.000000  18020.000000
# mean       0.094947      0.270498          0.249757      0.193575
# std        0.093184      0.355148          0.377174      0.156702
# ...

# %%
# Get the name of the songs with the 10 highest speechiness
df.sort_values(by = 'speechiness', ascending = False).head(10)
# Out:
#                            name  danceability  energy  key  loudness  mode  \
# 6316                Paul - Skit         0.636  0.3350   11   -13.327     1
# 9373         Kleine Geheimnisse         0.687  0.2480    2   -14.832     1
# 4983                Père & mère         0.640  0.3560    1   -11.318     1
# 14971   Unicorn Shave Your Horn         0.786  0.0344    5   -16.945     0
# 11995       Live from New York!         0.462  0.2910    5   -15.104     1
# 14098  Introduction - Live 1993         0.716  0.3390    2   -18.137     1
# 7400      Confessions nocturnes         0.531  0.8770    0    -6.604     0
# 10940                     D.ieu         0.605  0.5440    1    -9.942     1
# 978        Bowls Whirling Water         0.358  0.9140   11   -19.331     0
# 10055                 No Barkin         0.697  0.3360    6    -8.546     1
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 6316         0.966         0.993            0.0000     0.342   0.5610
# ...

# %%
# I want to have an area colored from green to red depending on the stats of a variable of a dataframe

# %%
# songs in the db are approximately 207s long so need ~18 to have an hour played

# %%
# get the distribution of the variable
dist = df['danceability'].hist()
# use the distribution as a color palette
# dist = dist.get_figure()
dist.values
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\james\Documents\spotify\stats_on_db.ipynb Cell 7 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/james/Documents/spotify/stats_on_db.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> dist = df['danceability'].hist()
#       <a href='vscode-notebook-cell:/c%3A/Users/james/Documents/spotify/stats_on_db.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> # use the distribution as a color palette
#       <a href='vscode-notebook-cell:/c%3A/Users/james/Documents/spotify/stats_on_db.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a> # dist = dist.get_figure()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/james/Documents/spotify/stats_on_db.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a> dist.values
#
# AttributeError: 'Axes' object has no attribute 'values'
