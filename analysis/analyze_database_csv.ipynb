# %%
import os
import json
import sys
sys.path.append(os.path.join(os.path.dirname('.'), '..'))
from Database import Database

# %%
with open("../Playlists/playlists.json", "r") as file:
    playlists = json.load(file)

# %%
playlists
# Out:
# {'Deep concentration': {'Deep Focus': 'https://open.spotify.com/playlist/37i9dQZF1DWZeKCadgRdKQ?si=826dfc2ad38641cf',
#   'Perfect Concentration': 'https://open.spotify.com/playlist/37i9dQZF1DWSluGMsH1R9r?si=5a3c08dfa7664fcb',
#   'Focus Jazz': 'https://open.spotify.com/playlist/37i9dQZF1DX8wWHvPMMfNA?si=3c754e20949f413a',
#   'Classical Focus': 'https://open.spotify.com/playlist/37i9dQZF1DXd5zUwdn6lPb?si=a40aced3cf4e448c',
#   'Focus Flow': 'https://open.spotify.com/playlist/37i9dQZF1DWZZbwlv3Vmtr?si=1c1218a1b5a14d27',
#   'Boom Bap Focus': 'https://open.spotify.com/playlist/37i9dQZF1DX45qfzFXwcta?si=a20618c7e52845b9',
#   'Positive Focus': 'https://open.spotify.com/playlist/37i9dQZF1DWYmSg58uBxin?si=2163c1b8707d4dbc',
#   'Atmospheric Focus': 'https://open.spotify.com/playlist/37i9dQZF1DXaf6XmhwlgC6?si=7a80ddd19d9a4111',
#   'Chilled Focus': 'https://open.spotify.com/playlist/37i9dQZF1DWYRcvdDwEl3O?si=4d9d783bbba54844',
# ...

# %%
for playlist in playlists:
    print(playlist)
# Out:
# Deep concentration
# Popular Focus playlists
# Slow
# Lofi Moods & Moments
# Relaxing Classical
# Ambient 101
# Dig Deeper in Sound
# Ambient Moods & Moments
# Classical Ambient
# Experimental Ambient
# New Age
# Track IDs
# DJ mixes
# Popular Dance/Electronic playlists
# Coding
# Personal

# %%
db = Database("james", "Kkatecalisti98", "spotifydb")
playlists_name = db.get_playlist_names()

# %%
playlists_name[0]
# Out:
# ('37i9dQZF1DWZeKCadgRdKQ',
#  'Deep Focus',
#  'Keep calm and focus with ambient and post-rock music.',
#  4050548,
#  'https://i.scdn.co/image/ab67706f00000003d6d48b11fd3b11da654c3519',
# ...

# %%
new_playlists = {}
for key1, values in playlists.items():
    new_playlists[key1] = {}
    print(len(values))
    for key2, value in values.items():
        id = value.split("/")[-1].split("?")[0]
        for playlist_name in playlists_name:
            if id == playlist_name[0]:
                new_playlists[key1][playlist_name[1]] = value
                break
    print(f"Then {len(values)}")
# Out:
# 14
# Then 14
# 107
# Then 107
# 8
# Then 8
# 16
# Then 16
# 25
# Then 25
# 6
# Then 6
# 5
# Then 5
# 20
# Then 20
# 9
# Then 9
# 5
# Then 5
# 13
# Then 13
# 4
# Then 4
# 1
# Then 1
# 23
# Then 23
# 3
# Then 3
# 3
# Then 3

# %%
with open("../Playlists/playlists.json", "w") as file:
    json.dump(new_playlists, file, indent=4)

# %%
import os
import json
import sys
import pandas as pd

# %%
playlists = pd.read_csv(r"C:\Users\james\Downloads\playlists_db.csv", header = None, names = ['id', 'name', 'description', 'followers', 'images', 'tracks'])
features = pd.read_csv(r"C:\Users\james\Downloads\features_db.csv", header = None, names = ['id', 'name', 'popularity', 'followers', 'images', 'genres'])
artists = pd.read_csv(r"C:\Users\james\Downloads\artists_db.csv", header = None, names = ['name', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'type', 'id'])
# Out:
# C:\Users\james\AppData\Local\Temp\ipykernel_4768\4199286100.py:2: DtypeWarning: Columns (12,14,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   features = pd.read_csv(r"C:\Users\james\Downloads\features_db.csv", header = None, names = ['id', 'name', 'popularity', 'followers', 'images', 'genres'])
# C:\Users\james\AppData\Local\Temp\ipykernel_4768\4199286100.py:3: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   artists = pd.read_csv(r"C:\Users\james\Downloads\artists_db.csv", header = None, names = ['name', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'type', 'id'])

# %%
playlists
# Out:
#                          id                   name  \
# 0    37i9dQZF1DWZeKCadgRdKQ             Deep Focus
# 1    37i9dQZF1DWSluGMsH1R9r  Perfect Concentration
# 2    37i9dQZF1DX8wWHvPMMfNA             Focus Jazz
# 3    37i9dQZF1DXd5zUwdn6lPb        Classical Focus
# 4    37i9dQZF1DWZZbwlv3Vmtr             Focus Flow
# ..                      ...                    ...
# 251  37i9dQZF1DX7RL0gBxlbK0           Rave Factory
# 252  37i9dQZF1EIeKh45OZ1ylm             Techno Mix
# 253  7mwPa6HjqoiUrsk3C2Hitk       Best Techno 2023
# 254  4G6L0C9Tr0QSQXuk03tUbJ      RAVE PARTY 2023 🔊
# 255  0gdwyxYM0QGEaPezHZqqVs               Techno 🔞
#
#                                            description  followers  \
# 0    Keep calm and focus with ambient and post-rock...    4050548
# 1         Calm piano music for enhanced concentration.     685458
# 2      Soft instrumental jazz for working or studying.     222822
# 3             Enhance your focus with classical music.     281267
# ...
