# %%
from datetime import date, datetime as dt, timedelta as td
import numpy as np
import pandas as pd
import datetime

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
# %matplotlib inline

# %%
heartbeats = pd.read_csv('../data/wakatime_heartbeats.csv')
# if exists remove old index columns
heartbeats.drop(['Unnamed: 0'], axis=1, inplace=True)
heartbeats
# Out:
#                                                  entity  type  \
# 0     C:/Users/james/Documents/spotify/UpdateDatabas...  file
# 1     C:/Users/james/Documents/personal-influxdb/con...  file
# 2     C:/Users/james/Documents/personal-influxdb/con...  file
# 3     C:/Users/james/Documents/personal-influxdb/con...  file
# 4     C:/Users/james/Documents/personal-influxdb/res...  file
# ...                                                 ...   ...
# 1029  C:/Users/james/Documents/spotify/GUI/RescueWak...  file
# 1030  C:/Users/james/Documents/spotify/GUI/RescueWak...  file
# 1031  C:/Users/james/Documents/spotify/GUI/RescueWak...  file
# 1032  C:/Users/james/Documents/spotify/GUI/RescueWak...  file
# 1033  C:/Users/james/Documents/spotify/GUI/RescueWak...  file
#
#                             time            project language  \
# 0     2023-10-20 10:58:10.719354            spotify   Python
# 1     2023-10-20 13:20:05.720760  personal-influxdb   Python
# 2     2023-10-20 13:24:00.772098  personal-influxdb   Python
# 3     2023-10-20 13:24:33.862740  personal-influxdb   Python
# 4     2023-10-20 13:25:26.129209  personal-influxdb   Python
# ...                          ...                ...      ...
# 1029  2023-10-25 08:11:55.457913            spotify   Python
# 1030  2023-10-25 08:12:01.779745            spotify   Python
# 1031  2023-10-25 08:14:32.107425            spotify   Python
# 1032  2023-10-25 08:16:39.403372            spotify   Python
# 1033  2023-10-25 08:18:50.363286            spotify   Python
#
#                                            dependencies  is_write   category  \
# 0     ['argparse', 'pandas', 'json', 'typing', 'tqdm...     False     coding
# 1           ['logging', 'pytz', 'influxdb', 'colorlog']     False     coding
# 2           ['logging', 'colorlog', 'influxdb', 'pytz']     False     coding
# 3           ['logging', 'pytz', 'influxdb', 'colorlog']      True     coding
# 4            ['datetime', 'config', 'requests', 'pytz']     False     coding
# ...                                                 ...       ...        ...
# 1029  ['rauth', 'matplotlib', 'tkinter', 'colour', '...     False  debugging
# 1030  ['rauth', 'matplotlib', 'tkinter', 'colour', '...      True  debugging
# 1031  ['tkinter', 'pickle', 'matplotlib', 'pandas', ...      True  debugging
# 1032  ['rauth', 'matplotlib', 'tkinter', 'colour', '...      True  debugging
# 1033  ['rauth', 'matplotlib', 'tkinter', 'colour', '...      True  debugging
#
#                 created_at                       machine_name_id
# 0     2023-10-20T08:58:12Z  018b4c4e-87d3-487a-b4f5-b0e649819022
# 1     2023-10-20T11:20:06Z  018b4c4e-87d3-487a-b4f5-b0e649819022
# 2     2023-10-20T11:24:01Z  018b4c4e-87d3-487a-b4f5-b0e649819022
# 3     2023-10-20T11:24:35Z  018b4c4e-87d3-487a-b4f5-b0e649819022
# 4     2023-10-20T11:25:27Z  018b4c4e-87d3-487a-b4f5-b0e649819022
# ...                    ...                                   ...
# 1029  2023-10-25T06:12:02Z  018b5758-ab91-483d-85b8-e4d4faf4ec77
# 1030  2023-10-25T06:12:06Z  018b5758-ab91-483d-85b8-e4d4faf4ec77
# 1031  2023-10-25T06:14:34Z  018b5758-ab91-483d-85b8-e4d4faf4ec77
# 1032  2023-10-25T06:16:42Z  018b5758-ab91-483d-85b8-e4d4faf4ec77
# 1033  2023-10-25T06:18:54Z  018b5758-ab91-483d-85b8-e4d4faf4ec77
#
# [1034 rows x 10 columns]
